# %%
data = [2,43,54,12,76,87,12]

# %%
data
# Out:
# [2, 43, 54, 12, 76, 87, 12]

# %%
import pandas as pd
data2 = pd.read_csv("Iris.csv")

# pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/Iris.csv")

# Above method is used read csv file directly from dataset link if running on google colab or other online notebooks

# %%
data2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data3 = pd.read_csv("Titanic.csv")

# %%
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data
# Out:
# [2, 43, 54, 12, 76, 87, 12]

# %%
data_copy = data.copy()

# %%
data_copy
# Out:
# [2, 43, 54, 12, 76, 87, 12]

# %%
# mean
# median
# mode

# %%
import numpy as np

np.mean(data_copy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 import numpy as np
# ----> 3 np.mean(data_copy)
#
# NameError: name 'data_copy' is not defined

# %%
np.median(data_copy)
# Out:
# 43.0

# %%
np.mean(data2.SepalLengthCm)
# Out:
# 5.843333333333334

# %%
np.median(data2.SepalLengthCm)
# Out:
# 5.8

# %%
# mode

np.mode(data_copy)

# Error means numpy does not have mode feature to calculate
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 # mode
# ----> 3 np.mode(data_copy)
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:320, in __getattr__(attr)
#     317     from .testing import Tester
#     318     return Tester
# --> 320 raise AttributeError("module {!r} has no attribute "
#     321                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
# so this library will be used

import statistics

statistics.mode(data_copy)
# Out:
# 12

# %%
# scipy can also give mode value with count of the value

from scipy import stats as st

st.mode(data_copy)
# Out:
# ModeResult(mode=12, count=2)

# %%
data
# Out:
# [2, 43, 54, 12, 76, 87, 12]

# %%
s = 0
for i in data:
    s+=i
    
mean = s/len(data)

print(mean)
# Out:
# 40.857142857142854

# %%
# same as

np.mean(data)
# Out:
# 40.857142857142854

# %%
data_copy.append(150)

# %%
data_copy.pop()
# Out:
# 150

# %%
data_copy
# Out:
# [2, 43, 54, 12, 76, 87, 12, 150]

# %%
np.mean(data_copy)
# Out:
# 54.5

# %%
np.mean(data)   # big difference due adding one outlier or out of the box value
# Out:
# 40.857142857142854

# %%
np.median(data_copy)
# Out:
# 48.5

# %%
np.median(data)  # no much difference in median that is why we use median in case of outliers as data distribution is changing
# Out:
# 43.0

# %%
#dispersion


np.percentile(data,[25])  #here we are giving at which percent we want percentile data
# Out:
# array([12.])

# %%
np.percentile(data,[50])
# Out:
# array([43.])

# %%
np.percentile(data,[25,50,75,100])  # all four quartile values
# Out:
# array([12., 43., 65., 87.])

# %%
# lets check

data_copy
# Out:
# [2, 43, 54, 12, 76, 87, 12, 150]

# %%
data_copy.pop()
# Out:
# 150

# %%
data_copy
# Out:
# [2, 43, 54, 12, 76, 87, 12]

# %%
data_copy.sort()

# %%
data_copy
# Out:
# [2, 12, 12, 43, 54, 76, 87]

# %%
data_copy.append(200)

# %%
data_copy
# Out:
# [2, 12, 12, 43, 54, 76, 87, 200]

# %%
#quartile

#q1,q2,q3,q4

# IQR = q3 - q1

# lower fence = q1 -IQR *1.5   --- Below this no. will be outlier

#upper fence = q2 +IQR* 1.5   --- above this will be outlier

import seaborn as sns

sns.boxplot(data_copy)
# Out:
# <Axes: >

# %%
# sample and population
# we can collect sample value with many way. One of the way is random sampling

# %%
np.random.choice(data)
# Out:
# 54

# %%
np.random.choice(data)  # each time different with same data set
# Out:
# 43

# %%
np.random.choice(data, size=3)  # here I am taking 3 value randomly each time which give different value each time
# Out:
# array([87, 43, 12])

# %%
data2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# for this data we can find sample data by sample function

data2.sample()  #it gives by default one row
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
data2.sample(n=10)  # for more than one row we need to give row no. and it will give different set of sample data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 32    33            5.2           4.1            1.5           0.1
# 78    79            6.0           2.9            4.5           1.5
# 87    88            6.3           2.3            4.4           1.3
# 109  110            7.2           3.6            6.1           2.5
# 119  120            6.0           2.2            5.0           1.5
# 132  133            6.4           2.8            5.6           2.2
# 74    75            6.4           2.9            4.3           1.3
# 19    20            5.1           3.8            1.5           0.3
# 122  123            7.7           2.8            6.7           2.0
# 143  144            6.8           3.2            5.9           2.3
#
#              Species
# 32       Iris-setosa
# 78   Iris-versicolor
# 87   Iris-versicolor
# 109   Iris-virginica
# 119   Iris-virginica
# 132   Iris-virginica
# 74   Iris-versicolor
# 19       Iris-setosa
# 122   Iris-virginica
# ...

# %% [markdown]
# ## search 5 type of sampling technique and implement
#
# ### Simple random sampling
# You want to select a simple random sample of 1000 employees of a social media marketing company. You assign a number to every employee in the company database from 1 to 1000, and use a random number generator to select 100 numbers.
#
# ### Systematic sampling
# All employees of the company are listed in alphabetical order. From the first 10 numbers, you randomly select a starting point: number 6. From number 6 onwards, every 10th person on the list is selected (6, 16, 26, 36, and so on), and you end up with a sample of 100 people.
#
# ### Stratified sampling
# The company has 800 female employees and 200 male employees. You want to ensure that the sample reflects the gender balance of the company, so you sort the population into two strata based on gender. Then you use random sampling on each group, selecting 80 women and 20 men, which gives you a representative sample of 100 people.
#
# ### Cluster sampling
# The company has offices in 10 cities across the country (all with roughly the same number of employees in similar roles). You don’t have the capacity to travel to every office to collect your data, so you use random sampling to select 3 offices – these are your clusters.
#
# ### Convenience Sampling:
# This is a non-probability sampling technique where the sample is selected based on convenience or accessibility. This technique is not ideal for statistical inference, as it is not representative of the population.

# %%
# for variance

def varr(data):
    s = 0
    for i in data:
        s = s + (i - np.mean(data))**2/(len(data)-1)
        
    return s

# need to recheck

# %%
# n-1 is sample and n is population

print(varr(data))  ## this result is coming as we are diving with n-1 (n = no. of sample)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 # n-1 is sample and n is population
# ----> 3 print(varr(data))
#
# NameError: name 'data' is not defined

# %%
# variance and standard daviation

np.var(data)   # it is using division of n in the variance
# Out:
# 959.5510204081633

# %%
np.std(data)
# Out:
# 30.976620545310674

# %%
statistics.variance(data)  # it is using division of n-1 in the variance
# Out:
# 1119.4761904761904

# %%
statistics.pvariance(data)   # it is giving population variance
# Out:
# 959.5510204081633

# %%
import math

math.sqrt(statistics.pvariance(data))  # as square root of variance is standard daviation
# Out:
# 30.976620545310674

# %% [markdown]
# # Correlation and covariance

# %%
data2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data4 = [[12,23,54,13],[43,65,87,32]]

# %%
data4
# Out:
# [[12, 23, 54, 13], [43, 65, 87, 32]]

# %% [markdown]
# data.corr()  --- > It will give correlation between the varible of of column from inside dataset
#
# data.cov()  ----> It is for getting covariance

# %%
import seaborn as sns

sns.scatterplot(x=data2['SepalLengthCm'], y=data2['PetalWidthCm'])

#  If
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# # PDF -- Probability distribution function

# %%
sns.histplot(data2)
# Out:
# <Axes: ylabel='Count'>

# %%
sorted(data)

sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data,kde=True)  # kde is kernal densty funcion which is used to check smoothen of data ploted in histogram
# Out:
# <Axes: ylabel='Count'>

# %%
data2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.histplot(data2['SepalLengthCm'])
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(data2['SepalLengthCm'],kde=True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(data2['SepalWidthCm'],kde=True)  # perfect log normal distribution
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(data2['PetalLengthCm'],kde=True)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
data_copy = data.copy()

# %%
data_copy2 = data.copy()

# %%
data_copy2
# Out:
# [2, 43, 54, 12, 76, 87, 12]

# %%
data_copy
# Out:
# [2, 43, 54, 12, 76, 87, 12]

# %%
data_copy.append(287)

# %%
data_copy.sort()

# %%
data_copy
# Out:
# [2, 12, 12, 43, 54, 76, 87, 100, 179, 200, 287]

# %%
sns.histplot(data_copy,kde=True) #  ---- Proper right skewed
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy2[0] = -10

# %%
data_copy2
# Out:
# [-10, 43, 54, 12, 76, 87, 12]

# %%
data_copy2[0] = -50

# %%
data_copy2
# Out:
# [-50, 43, 54, 12, 76, 87, 12]

# %%
data_copy2[1] = -20

# %%
data_copy2
# Out:
# [-50, -20, 54, 12, 76, 87, 12]

# %%
data_copy2.pop(-1)
# Out:
# 200

# %%
data_copy2
# Out:
# [-50, -20, 54, 12, 76, 87, 12]

# %%
sns.histplot(data_copy2,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data2['PetalWidthCm'],kde=True)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %%
import numpy as np

s=np.random.normal(0.5,0.2, 1000)   #  inside normal we have mean, standard devation, no. of points


# this normal function in numpy --  we are using to generate normally distributed data points

# %%
sns.histplot(s,kde=True)  # So it is normal distributed graph

# At any point in y axis we can get its probablity value
# Out:
# <Axes: ylabel='Count'>

# %%
nu ,sigma = 0.3, 1.0

p = np.random.lognormal(nu,sigma,1000)  # generating lognormal distribution data points

# %%
sns.histplot(p,kde=True)   # Here are getting log normal distribution or right skewed graph from the generated data ponts
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(p),kde=True)   # So if we will apply of log right skewed or log normal distribution it will convert into
# normal distribution
# Out:
# <Axes: ylabel='Count'>

# %%
# so lets check iris data set value to convert to normal distribution and check if it converting that

sns.histplot(data2['SepalLengthCm'],kde=True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(np.log(data2['SepalLengthCm']),kde=True)   # Kind of changing to normal by using log in value
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(data2['PetalLengthCm'],kde=True)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.histplot(np.log(data2['PetalLengthCm']),kde=True)   # it is applying on both curve
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab


def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample, kde=True)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)   # Here we are checking Q-Q Plot to check if data point is normally 
    plt.show()                                     # ditributed or not. For that all data point should be in one line in 
                                                    # 2nd graph
plot_data(data)


''' A histogram is a bar graph that shows the frequency of different values in the data. 
A Q-Q plot compares the quantiles of the data to the quantiles of a normal distribution. 
If the data is normally distributed, then the points on the Q-Q plot should fall approximately along a straight line.



The Quantile-Quantile plot is used for the following purpose:

Determine whether two samples are from the same population.
Whether two samples have the same distribution shape

'''


# this data is not normally distributed
# Out:
# ' A histogram is a bar graph that shows the frequency of different values in the data. \nA Q-Q plot compares the quantiles of the data to the quantiles of a normal distribution. \nIf the data is normally distributed, then the points on the Q-Q plot should fall approximately along a straight line.'

# %%
# lets check for some other datasets

plot_data(data_copy)   # it is right skewed and it is also not normally distributed

# %%
# lets check for random normal value dataset which we generated

plot_data(s)   # so this is correct normally distributed dataset as points are on line

# %%
# lets check for random log normal value dataset which we generated

plot_data(p) # it is right skewed and data points are not in straigt line so it is not normal distributed

# %%
# lets make make this right skewed graph normal distribution


plot_data(np.log(p))   # again all points are in one line as we are chaning log normal to normal distribution using log

# %% [markdown]
# # Pandas Profiling to check the complete details of dataset

# %%
import pandas as pd

data3 = pd.read_csv("Titanic.csv")

# %%
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# !pip install pandas-profiling

# %%
# These below code will provide yhe detailed analysis of data of dataset with proper html form with all the graphs and 
# variable relationship. In short all EDA will be provided together

# we can follow this link for more details: https://towardsdatascience.com/accelerate-your-exploratory-data-analysis-with-pandas-profiling-4eca0cb770d1#:~:text=Installation%20in%20Google%20Colab,6).

import pandas_profiling

profile = data3.profile_report()

# %%
profile.to_file("output.html")
